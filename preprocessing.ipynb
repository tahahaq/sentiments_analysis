# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("filetoprocess.csv")

# %%
df.head()
# Out:
#               tweet_id  screen_name                  utc_date  \
# 0  1225381931568836610        xtp00  2020-02-06T11:33:13.000Z
# 1  1225381893408989184       _0ward  2020-02-06T11:33:04.000Z
# 2  1225381877705408513    Stc_Kuhri  2020-02-06T11:33:00.000Z
# 3  1225381780443869184  qadsawi1991  2020-02-06T11:32:37.000Z
# 4  1225381770926993408   MR_3BDAL77  2020-02-06T11:32:35.000Z
#
#            pacific_time               source  favorites  retweets lang  \
# 0  2/6/2020, 3:33:13 AM   Twitter for iPhone          0         0   ar
# 1  2/6/2020, 3:33:04 AM  Twitter for Android          0        40   ar
# 2  2/6/2020, 3:33:00 AM   Twitter Web Client          0         0   ja
# 3  2/6/2020, 3:32:37 AM  Twitter for Android          0         7   ar
# 4  2/6/2020, 3:32:35 AM  Twitter for Android          0         1   ar
#
#                                                 text quote place  latitude  \
# 0                              @FarohaM كل ابراج stc   NaN   NaN       NaN
# 1  RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...   NaN   NaN       NaN
# 2  さっき吉野家行ったんですよ、吉野家。\n店内で食うの嫌だから、テイクアウトするために。\nそ...   NaN   NaN       NaN
# 3  RT @m_madridi : مواجهات نادي القادسية في شهر ف...   NaN   NaN       NaN
# 4  RT @3rbawei93 : غيابات العربي غداً أمام الساحل...   NaN   NaN       NaN
#
#    longitude media_type media tweet_type  original_tweet_id
# 0        NaN        NaN   NaN      reply                NaN
# 1        NaN        NaN   NaN    retweet       1.225363e+18
# 2        NaN        NaN   NaN      tweet                NaN
# 3        NaN        NaN   NaN    retweet       1.225169e+18
# 4        NaN        NaN   NaN    retweet       1.225382e+18

# %%
df['text'][1]
# Out:
# 'RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع \u2066♥️\u2069\n\n👌مناسبة لل🎼 متاجر 🎼 حسابات شخصية ..\n\nحساب للبيع 👌\n\n\u2066\u2066♥️\u2069\u20695 آلاف متابع \n⚫7 آلاف متابع \n\u2066♥️\u206911 ألف متابع \n\n\u2066📉\u2069\u2069 نقبل تحويل بنكي ع الاهلي والراجحي وشحن STC\n\n\u2066 للتواصل خاص فقط🎨 \n\n#ماذا_يغضب_البنات https://t.co/f5mMpXaR7d'

# %%
df.columns
# Out:
# Index(['tweet_id', 'screen_name', 'utc_date', 'pacific_time', 'source',
#        'favorites', 'retweets', 'lang', 'text', 'quote', 'place', 'latitude',
#        'longitude', 'media_type', 'media', 'tweet_type', 'original_tweet_id'],
#       dtype='object')

# %%
df_new=df[['lang','text']]

# %%
len(df_new)
# Out:
# 2276

# %%
df_new['text'][1]
# Out:
# 'RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع \u2066♥️\u2069\n\n👌مناسبة لل🎼 متاجر 🎼 حسابات شخصية ..\n\nحساب للبيع 👌\n\n\u2066\u2066♥️\u2069\u20695 آلاف متابع \n⚫7 آلاف متابع \n\u2066♥️\u206911 ألف متابع \n\n\u2066📉\u2069\u2069 نقبل تحويل بنكي ع الاهلي والراجحي وشحن STC\n\n\u2066 للتواصل خاص فقط🎨 \n\n#ماذا_يغضب_البنات https://t.co/f5mMpXaR7d'

# %%
df_new.isna().sum()
# Out:
# lang    0
# text    0
# dtype: int64

# %%
df_new.isnull().sum()
# Out:
# lang    0
# text    0
# dtype: int64

# %%
df_new['lang']=df_new[df_new.lang== 'ar']
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
len(df_new)
# Out:
# 2276

# %%
df_new.head()
# Out:
#   lang                                               text
# 0   ar                              @FarohaM كل ابراج stc
# 1   ar  RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 2  NaN  さっき吉野家行ったんですよ、吉野家。\n店内で食うの嫌だから、テイクアウトするために。\nそ...
# 3   ar  RT @m_madridi : مواجهات نادي القادسية في شهر ف...
# 4   ar  RT @3rbawei93 : غيابات العربي غداً أمام الساحل...

# %%
df_new.dropna(inplace=True)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
len(df_new)
# Out:
# 1033

# %%
df_new.head()
# Out:
#   lang                                               text
# 0   ar                              @FarohaM كل ابراج stc
# 1   ar  RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 3   ar  RT @m_madridi : مواجهات نادي القادسية في شهر ف...
# 4   ar  RT @3rbawei93 : غيابات العربي غداً أمام الساحل...
# 7   ar  @M3r5al مساء الخير محمد\n\nعشان نقوم معاك بالو...

# %%
df_new['text']
# Out:
# 0                                   @FarohaM كل ابراج stc
# 1       RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 3       RT @m_madridi : مواجهات نادي القادسية في شهر ف...
# 4       RT @3rbawei93 : غيابات العربي غداً أمام الساحل...
# 7       @M3r5al مساء الخير محمد\n\nعشان نقوم معاك بالو...
# 8       غيابات العربي غداً أمام الساحل في دوري STC الم...
# 9       @al_zahrani071 @stc_ksa @CITC_SA أهلًا بك أ. أ...
# 10      RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 11      RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 12      RT @Z_alshatti36 : 🗓 اليوم\n\n⚽️ ضمن دوري STC ...
# 13      RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 14                         @Bdah2424 زفت انا غيرتها ل stc
# 17                    @stc_ksa \nنتكم امرضني والله امرضني
# 19                                     يالله أنك تلعن stc
# 20      RT @3rbawei93 : حصري :\nالطاقم التحكيمي لمبارا...
# 23      RT @3rbawei93 : حصري :\nالطاقم التحكيمي لمبارا...
# 24      RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 25      RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 26      RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 28      RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 29      RT @ssaari101010 : @Adeltayeb مرة دخلت ع stc  ...
# 30      @fahadaljabre يا هلا فيك ومرحبا، سعيدين بتواصل...
# 33      RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 35      RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 37      RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
# 38      RT @ALDERBYSHOW : توقعات الرواد لقمة #الكويت و...
# 39      @Adeltayeb مرة دخلت ع stc  بدل ما اسلم قلت الو...
# 40      RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 41      RT @mohammadshoweir : @stcpay_ksa ▪️للأسف يا S...
# 42      RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع ⁦♥...
#                               ...
# 2126    @stc_ksa طيب انا ابى اغير من الباقه الي انا في...
# 2137    @stc_ksa ياخي الله يرحم والديكم نبي الياف انا ...
# 2151    RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 2152    RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 2154    RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 2165    لا رحت محطه يعلك يقولك ما عنده stc pay #تحدي_ر...
# 2166    RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 2167    RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 2171                              @stc_ksa مدينتي / الخبر
# 2173    RT @khalidalfadli : من تكريم النجم فهد المجمد-...
# 2176    RT @3ff3z : حول الأموال دوليا وفوريا عبر جوالك...
# 2181    RT @3ff3z : حول الأموال دوليا وفوريا عبر جوالك...
# 2185    @jnoobi_hor3 @6BQlSGejo2Szfep @STCSouthArabia ...
# 2187    @stc_ksa وش الفايده وحارتنا مافيها هذاك البوكس...
# 2191    @Plat017 حياك الله .. لو سمحت تفضل بالتواصل مع...
# 2199    @stcpay_ksa وانا اقول ليش stc خدماتهم صارة زفت...
# 2205    @Nasoma48215598 @stc_ksa في ذي صاادقه الفاتوره...
# 2206    RT @jnoobi_hor3 : ✋✋✋\n@STCSouthArabia \n@NA_O...
# 2209    RT @AboslimanQasim : موظفي #فودافون_مصر  بعد ا...
# 2212    @BRQTAIF حياك الله\nعشان نقوم معاك بالواجب توا...
# 2217    RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 2222    RT @3ff3z : حول الأموال دوليا وفوريا عبر جوالك...
# 2224    @abuyazed434 @stccare_ksa محمد الحربي والله ان...
# 2228    @stc_ksa كلام فاضي ذا السحب ما احد فاز بها في ...
# 2231    RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 2243    RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 2246    RT @AlmjlesAlarbawi : ⚽️ موعد المباراة القادمة...
# 2247    RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_الرا...
# 2251    @ZainHelpSA وين تجيني خاص تبا تخدمني ماخدمتوني...
# 2257    @stc_ksa يارب العالمين انها من نصيبي يالله يار...
# Name: text, Length: 1033, dtype: object

# %%
df_new['text'].to_csv(r'C:\Users\Humna Shafqat\Desktop\python\sentimant_analysis\tweet_text.csv')
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
path=r"C:\Users\Humna Shafqat\Desktop\python\sentimant_analysis\tweet_text.tsv"

# %%
from itertools import islice
def load_tsv(data_file, n):
    data_features = list()
    data = list()
    infile = open(data_file, encoding='utf-8')
    for line in infile:
        if not line.strip():
            continue
        text = line.split('\t')
        text_features = process_text(text, n)
        if text_features:
            data_features += text_features
            data.append((text_features, label))
    return data, data_features

def process_text(text, n=1,
                 remove_vowel_marks=False,
                 remove_repeated_chars=False,
                 ):
    clean_text = text
    if remove_vowel_marks:
        clean_text = remove_diacritics(clean_text)
    if remove_repeated_chars:
        clean_text = remove_repeating_char(clean_text)

    if n == 1:
        return clean_text.split()
    else:
        tokens = clean_text.split()
        grams = tokens
        for i in range(2, n + 1):
            grams += [  ' '.join(g) for g in list(window(tokens, i))  ]
        return grams

# %%
print('parameters')
n = 1

print('n grams:', n)
# Out:
# parameters
# n grams: 1

# %%
from textutil import *
test_data = read_tsv(path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-58-f16fc853479f> in <module>
# ----> 1 from textutil import *
#       2 test_data = read_tsv(path)
#
# ModuleNotFoundError: No module named 'textutil'

# %%
a=[]
b=[]
infile = open(path, encoding='utf-8')
for line in infile:
    a.append(line)

# %%
print(a)
# Out:
# ['@FarohaM كل ابراج stc\n', '"RT @ins660 : 🎨 بيع حسابات انستقرام 🇸🇦 للبيع \u2066♥️\u2069\n', '\n', '👌مناسبة لل🎼 متاجر 🎼 حسابات شخصية ..\n', '\n', 'حساب للبيع 👌\n', '\n', '\u2066\u2066♥️\u2069\u20695 آلاف متابع \n', '⚫7 آلاف متابع \n', '\u2066♥️\u206911 ألف متابع \n', '\n', '\u2066📉\u2069\u2069 نقبل تحويل بنكي ع الاهلي والراجحي وشحن STC\n', '\n', '\u2066 للتواصل خاص فقط🎨 \n', '\n', '#ماذا_يغضب_البنات https://t.co/f5mMpXaR7d"\n', '"RT @m_madridi : مواجهات نادي القادسية في شهر فبراير :\n', 'الكويت { STC } 6 فبراير ✈️\n', 'الرفاع البحريني { AFC } 11فبراير ✈️\n', 'اليرموك { STC } 15 فبراير 🏠\n', 'ظفار العماني{ AFC } 25فبراير 🏠#القادسية"\n', '"RT @3rbawei93 : غيابات العربي غداً أمام الساحل في دوري STC الممتاز :\n', '1️⃣ عبدالله الشمالي (إيقاف بسبب تراكم البطاقات الصفراء)\n', '2️⃣ مشاري الكندري (إصابة)\n', '3️⃣ علي مقصيد https://t.co/vHMXfBh7BJ"\n', '"@M3r5al مساء الخير محمد\n', '\n', 'عشان نقوم معاك بالواجب تواصل معنا على الخاص\n', 'يومك سعيد\n', 'https://t.co/8cd5h6bWrj"\n', '"غيابات العربي غداً أمام الساحل في دوري STC الممتاز :\n', '1️⃣ عبدالله الشمالي (إيقاف بسبب تراكم البطاقات الصفراء)\n', '2️⃣ مشاري الكندري (إصابة)\n', '3️⃣ علي مقصيد https://t.co/vHMXfBh7BJ"\n', '"@al_zahrani071 @stc_ksa @CITC_SA أهلًا بك أ. أحمد، يسعدنا خدمتك من خلال رفع الشكوى ""عدم تفعيل الخدمة"" عبر موقعنا الإلكتروني:\n', ' https://t.co/MqMKSJoiUi https://t.co/CrQJ90Hfch"\n', '"RT @stcpay_ksa : خطوة بخطوة مع #تحدي_رقصة_